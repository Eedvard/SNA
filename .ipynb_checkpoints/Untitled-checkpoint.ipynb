# %%
import sys

import matplotlib.pyplot as plt
import networkx as nx

# %%
g = nx.Graph()
#g.add_edges_from(
 #   [('A', 'B'), ('A', 'C'), ('D', 'B'), ('E', 'C'), ('E', 'F'),
  #   ('B', 'H'), ('B', 'G'), ('B', 'F'), ('C', 'G')])
#B = ["a","b","c","d","e"]
#A = [104, 11234, 543, 456, 346]
A = [104, 11234, 10000]
#g.add_nodes_from(A)
g.add_node("Hävittäjä")
g.add_node("Venäjä")
g.add_node("Nato")
g.add_edge("Hävittäjä", "Venäjä")
g.add_edge("Nato", "Venäjä")
g.add_edge("Nato", "Hävittäjä")


nx.draw(g, pos=nx.circular_layout(g), node_size=A, with_labels=True)
plt.show()
